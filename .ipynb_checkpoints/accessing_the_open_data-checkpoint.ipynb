# %% [markdown]
# # PORTO CITY DATA
#
#
# All the city data from Porto is indexed at Porto's CKAN platform: https://opendata.urbanplatform.portodigital.pt/.
#
# All the data is downloadable from the CKAN platform directly in various formats (CSV, images, etc...). The exception is the IoT data, which is available from a separate API endpoint, but which is indexed by CKAN.

# %% [markdown]
# # The CKAN Platform
#
# CKAN is a tool for making open data websites. (Think of a content management system like WordPress - but for data, instead of pages and blog posts). It helps you manage and publish collections of data.
#
# Once your data is published, users can use its faceted search features to browse and find the data they need, and preview it using maps, graphs and tables - whether they are developers, journalists, researchers, NGOs, citizens, or even your own staff.
#
# **Datasets and resources**
#
# For CKAN purposes, data is published in units called “datasets”. A dataset is a parcel of data - for example, it could be the crime statistics for a region, the spending figures for a government department, or temperature readings from various weather stations. When users search for data, the search results they see will be individual datasets.
#
# A dataset contains two things:
#
# * ***Metadata***: Information about the data.
# For example, the title and publisher, date, what formats it is available in, what license it is released under, etc.
# * ***Resources***: The data itself. CKAN does not mind what format the data is in. A resource can be a CSV or Excel spreadsheet, XML file, PDF document, image file, linked data in RDF format, etc. CKAN can store the resource internally, or store it simply as a link, the resource itself being elsewhere on the web.
#
# Note: On early CKAN versions, datasets were called “packages” and this name has stuck in some places, specially internally and on API calls. Package has exactly the same meaning as “dataset”.
#
# **API documentation**
# * CKAN: https://docs.ckan.org/en/2.8/api/
#
# **API endpoints**
# * CKAN: https://opendata.urbanplatform.portodigital.pt/api/3/

# %% [markdown]
# ## Available Data Sets & Resources
#
# Bellow you can find the API call which lists all available datasets.

# %%
## Porto's CKAN Platform examples
## Show all the datasets available (aka packages)

import pprint
import requests
url = "https://opendata.urbanplatform.portodigital.pt/api/3/action/package_list";
r = requests.get(url)
pprint.pprint(r.json())
# Out:
# {'help': 'https://opendata.urbanplatform.portodigital.pt/api/3/action/help_show?name=package_list',
#  'result': ['agua-de-nascente',
#             'alojamento-local',
#             'alojamentos-hoteleiros-2011',
#             'areas-edificadas',
#             'areas-verdes',
#             'atlas-desportivo',
#             'bairros-de-casas-economicas-do-estado-novo',
#             'balizas-de-sinalizacao',
#             'bicicletarios',
#             'carta-de-patrimonio',
#             'cemiterios-municipais-ou-privados-2007',
#             'centros-de-saude-e-extensoes-2001',
#             'ciclovias',
#             'correios-2013',
#             'dissuasores-de-controlo-de-acessos',
#             'ecocentros-2006',
#             'edificios-de-interesse-publico',
#             'edificios-de-interesse-publico-2012',
#             'eixos-de-via-infraestruturas-portugal',
#             'envolvente',
#             'equipamentos-de-recolha-contentores-cinzentos_-cones_recolha-de-objectos-fora-de-uso_-reee-e-vidroes',
#             'equipamentos-de-saude',
#             'espacos-verdes-com-valor-patrimonial-2012',
#             'estabelecimentos-de-bebidas-e-restauracao-da-movida-2012',
#             'estabelecimentos-de-ensino-por-ano-letivo',
#             'estabelecimentos-de-ensino-superior-por-ano-letivo',
#             'feiras-e-mercados-2011',
#             'fontes-de-contaminacao-cemiterios-carta-de-ocupacao-de-superficie',
#             'fontes-de-contaminacao-cemiterios-carta-hidrogeologica',
#             'fontes-de-contaminacao-depositos-de-lixo-misto-aterrados-carta-de-ocupacao-de-superficie',
#             'fontes-de-contaminacao-depositos-de-lixo-misto-aterrados-carta-hidrogeologica',
#             'fontes-de-contaminacao-entulheiras-aterradas-carta-de-ocupacao-de-superficie',
#             'fontes-de-contaminacao-entulheiras-aterradas-carta-hidrogeologica',
#             'fontes-de-contaminacao-entulheiras-carta-de-ocupacao-de-superficie',
#             'fontes-de-contaminacao-entulheiras-carta-hidrogeologica',
#             'fontes-de-contaminacao-lixeiras-aterradas-carta-de-ocupacao-de-superficie',
#             'fontes-de-contaminacao-lixeiras-aterradas-carta-hidrogeologica',
#             'fontes-de-contaminacao-sucatas-carta-de-ocupacao-de-superficie',
#             'fontes-de-contaminacao-sucatas-carta-hidrogeologica',
#             'furos-de-captacao-de-agua',
#             'georisk-carta-de-ocorrencias',
#             'georisk-carta-de-vulnerabilidade',
#             'hoteis_-aparthoteis-e-albergarias-centroides',
#             'informacao-publica-dos-servicos-de-transporte-colectivo-do-porto',
#             'limites-de-freguesias-1956',
#             'limites-de-freguesias-pos-reforma-da-lei-no-11-a-2013',
#             'metro-do-porto',
#             'nascentes',
#             'parcometros-zonas-de-estacionamento-pago',
#             'parques-de-estacionamento-municipais',
#             'parques-de-motociclos',
#             'patrimonio-mundial',
#             'pensoes_-residenciais-e-hospedarias-centroides',
#             'piscinas-centroides',
#             'pocos',
#             'porto-meteorologia',
#             'porto-niveis-ruido',
#             'porto-pontos-de-acesso-wifi-apd',
#             'porto-pontos-de-interesse',
#             'porto-qualidade-do-ar',
#             'porto-transito',
#             'porto-veiculos-do-municipio',
#             'postos-de-abastecimento-de-combustiveis-centroides',
#             'postos-de-informacao-turistica-centroides',
#             'praca-de-taxis',
#             'processos-de-fiscalizacao-ambito-do-dep-municipal-de-fiscalizacao',
#             'promocao-do-vinho-do-porto-centroides',
#             'quiosques-multimedia-centroides',
#             'recintos-musicais-centroides',
#             'recintos-polidesportivos-centroides',
#             'reparticoes-de-financas-e-tesourarias-servicos-centroides',
#             'restaurantes-centroides',
#             'ruido-zona-mista',
#             'ruido-zona-mista-2012',
#             'ruido-zona-sensivel',
#             'ruido-zona-sensivel-2012',
#             'sinalizacao-led-em-travessias-de-peoes',
#             'stcp-autocarros-paragens-centroides',
#             'superficies-comerciais-distribuicao-centroides',
#             'supermercados-e-hipermercados',
#             'teatros-centroides',
#             'templos-religiosos-centroides',
#             'transito_-impedimentos-e-obras-online',
#             'transportes-publicos-stcp',
#             'transportes-publicos-stcp-linhas',
#             'transportes-publicos-stcp-paragens',
#             'tribunais-centroides',
#             'zona-de-recolha-de-residuos',
#             'zonas-de-comercio-tradicional-centroides',
#             'zonas-instaveis-mais-criticas',
#             'zonas-instaveis-menos-criticas',
#             'zonas-potencialmente-instaveis'],
#  'success': True}

# %% [markdown]
# ## Resource
#
# You can find all kind of information regarding a dataset. Each dataset can have multiple resources, which can be accessed through the respective URL.

# %%
## Porto's CKAN Platform examples
## In this example we look at the parking zones in the city

import pprint
import requests
url = "https://opendata.urbanplatform.portodigital.pt/api/3/action/package_show?id=estabelecimentos-de-ensino-por-ano-letivo";
r = requests.get(url)
j = r.json()
print("Resources: ")
for resource in j['result']['resources']:
  print("{}({}):".format(resource['name'], resource['format']))
  print(resource['url'] + "\n")
print("Full resource information: ")
pprint.pprint(j)
# Out:
# Resources:
# Ensino Pré-Escolar (3-6 anos) e Básico 1º Ciclo (pontos) - público(Esri REST):
# https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/63
#
# Ensino Pré-Escolar (3-6 anos) e Básico 1º Ciclo (edificado) - público(Esri REST):
# https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/64
#
# Ensino Básico 2º, 3º Ciclo (pontos) - público(Esri REST):
# https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/65
#
# Ensino Básico 2º, 3º Ciclo (limites fundiários) - público(Esri REST):
# https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/66
#
# Ensino Secundário (pontos) - público(Esri REST):
# https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/67
#
# Ensino Secundário (limites fundiários) - público(Esri REST):
# https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/68
#
# Ensino Superior (pontos) - público e privado(Esri REST):
# https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/69
#
# Ensino Superior (edificado) - público e privado(Esri REST):
# https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/70
#
# Full resource information:
# {'help': 'https://opendata.urbanplatform.portodigital.pt/api/3/action/help_show?name=package_show',
#  'result': {'author': None,
#             'author_email': None,
#             'creator_user_id': '7fcadea2-e34e-44fa-aa32-e5d52da656c1',
#             'extras': [],
#             'groups': [{'description': 'Educação e Ciência',
#                         'display_name': 'Educação e Ciência',
#                         'id': 'cf8f9f9a-c995-47e7-9ebb-254b3937f13f',
#                         'image_display_url': '',
#                         'name': 'educacao-e-ciencia',
#                         'title': 'Educação e Ciência'}],
#             'id': '6ebbbf72-80bd-4b0e-b863-e22286f2919f',
#             'isopen': False,
#             'license_id': None,
#             'license_title': None,
#             'maintainer': None,
#             'maintainer_email': None,
#             'metadata_created': '2019-03-30T02:14:43.678636',
#             'metadata_modified': '2019-03-30T02:22:37.960269',
#             'name': 'estabelecimentos-de-ensino-por-ano-letivo',
#             'notes': 'Georreferenciação dos estabelecimentos de ensino, com as '
#                      'moradas, oferta de níveis de ensino e frequências '
#                      'escolares..',
#             'num_resources': 8,
#             'num_tags': 3,
#             'organization': {'approval_status': 'approved',
#                              'created': '2018-06-29T16:43:31.797549',
#                              'description': 'Câmara Municipal do Porto',
#                              'id': '27054936-759b-4127-a0c5-ef6bbe6140f3',
#                              'image_url': 'http://www.cm-porto.pt/assets/misc/img/logos/logo.svg',
#                              'is_organization': True,
#                              'name': 'cmporto',
#                              'revision_id': 'd6a1d1ca-f0e3-4fa7-bbb5-68cadf3ef266',
#                              'state': 'active',
#                              'title': 'C. M. Porto',
#                              'type': 'organization'},
#             'owner_org': '27054936-759b-4127-a0c5-ef6bbe6140f3',
#             'private': False,
#             'relationships_as_object': [],
#             'relationships_as_subject': [],
#             'resources': [{'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-03-30T02:14:44.049065',
#                            'datastore_active': False,
#                            'description': 'Ensino Pré-Escolar (3-6 anos) e '
#                                           'Básico 1º Ciclo (pontos) - público',
#                            'format': 'Esri REST',
#                            'hash': '',
#                            'id': 'f47b99f4-2ef0-423f-a76b-eb8fa1b89af5',
#                            'last_modified': None,
#                            'mimetype': None,
#                            'mimetype_inner': None,
#                            'name': 'Ensino Pré-Escolar (3-6 anos) e Básico 1º '
#                                    'Ciclo (pontos) - público',
#                            'package_id': '6ebbbf72-80bd-4b0e-b863-e22286f2919f',
#                            'position': 0,
#                            'resource_type': None,
#                            'revision_id': 'd6b6d0dc-a8cd-4f6d-8926-86a8cf196e34',
#                            'size': None,
#                            'state': 'active',
#                            'url': 'https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/63',
#                            'url_type': None},
#                           {'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-03-30T02:14:44.761406',
#                            'datastore_active': False,
#                            'description': 'Ensino Pré-Escolar (3-6 anos) e '
#                                           'Básico 1º Ciclo (edificado) - '
#                                           'público',
#                            'format': 'Esri REST',
#                            'hash': '',
#                            'id': '2c6dfcbe-bd44-4c80-89de-07b7944da116',
#                            'last_modified': None,
#                            'mimetype': None,
#                            'mimetype_inner': None,
#                            'name': 'Ensino Pré-Escolar (3-6 anos) e Básico 1º '
#                                    'Ciclo (edificado) - público',
#                            'package_id': '6ebbbf72-80bd-4b0e-b863-e22286f2919f',
#                            'position': 1,
#                            'resource_type': None,
#                            'revision_id': '11c2ab51-f954-413b-91be-b59631f9c867',
#                            'size': None,
#                            'state': 'active',
#                            'url': 'https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/64',
#                            'url_type': None},
#                           {'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-03-30T02:14:45.450559',
#                            'datastore_active': False,
#                            'description': 'Ensino Básico 2º, 3º Ciclo (pontos) '
#                                           '- público',
#                            'format': 'Esri REST',
#                            'hash': '',
#                            'id': '33f707a8-f5fb-4b52-84e5-3c7c8fcbad53',
#                            'last_modified': None,
#                            'mimetype': None,
#                            'mimetype_inner': None,
#                            'name': 'Ensino Básico 2º, 3º Ciclo (pontos) - '
#                                    'público',
#                            'package_id': '6ebbbf72-80bd-4b0e-b863-e22286f2919f',
#                            'position': 2,
#                            'resource_type': None,
#                            'revision_id': '24bc71cb-23e0-461b-a695-99f13c9a8918',
#                            'size': None,
#                            'state': 'active',
#                            'url': 'https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/65',
#                            'url_type': None},
#                           {'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-03-30T02:14:46.143499',
#                            'datastore_active': False,
#                            'description': 'Ensino Básico 2º, 3º Ciclo (limites '
#                                           'fundiários) - público',
#                            'format': 'Esri REST',
#                            'hash': '',
#                            'id': '55d00d95-6903-4ab2-b042-6a33e058afce',
#                            'last_modified': None,
#                            'mimetype': None,
#                            'mimetype_inner': None,
#                            'name': 'Ensino Básico 2º, 3º Ciclo (limites '
#                                    'fundiários) - público',
#                            'package_id': '6ebbbf72-80bd-4b0e-b863-e22286f2919f',
#                            'position': 3,
#                            'resource_type': None,
#                            'revision_id': '60a98e0c-7ed5-411f-a9f6-49d6899a9d09',
#                            'size': None,
#                            'state': 'active',
#                            'url': 'https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/66',
#                            'url_type': None},
#                           {'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-03-30T02:14:46.913906',
#                            'datastore_active': False,
#                            'description': 'Ensino Secundário (pontos) - '
#                                           'público',
#                            'format': 'Esri REST',
#                            'hash': '',
#                            'id': '849fbcab-2f03-4c29-a266-f353c4e1bd0a',
#                            'last_modified': None,
#                            'mimetype': None,
#                            'mimetype_inner': None,
#                            'name': 'Ensino Secundário (pontos) - público',
#                            'package_id': '6ebbbf72-80bd-4b0e-b863-e22286f2919f',
#                            'position': 4,
#                            'resource_type': None,
#                            'revision_id': '276399e1-2809-47b3-be23-4591403bba41',
#                            'size': None,
#                            'state': 'active',
#                            'url': 'https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/67',
#                            'url_type': None},
#                           {'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-03-30T02:14:47.689103',
#                            'datastore_active': False,
#                            'description': 'Ensino Secundário (limites '
#                                           'fundiários) - público',
#                            'format': 'Esri REST',
#                            'hash': '',
#                            'id': '095f7bb5-07f1-4586-b929-e3891e226878',
#                            'last_modified': None,
#                            'mimetype': None,
#                            'mimetype_inner': None,
#                            'name': 'Ensino Secundário (limites fundiários) - '
#                                    'público',
#                            'package_id': '6ebbbf72-80bd-4b0e-b863-e22286f2919f',
#                            'position': 5,
#                            'resource_type': None,
#                            'revision_id': '5cc97a78-5ba0-4e4e-8f25-8a152826e2d4',
#                            'size': None,
#                            'state': 'active',
#                            'url': 'https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/68',
#                            'url_type': None},
#                           {'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-03-30T02:14:49.495937',
#                            'datastore_active': False,
#                            'description': 'Ensino Superior (pontos) - público '
#                                           'e privado',
#                            'format': 'Esri REST',
#                            'hash': '',
#                            'id': '94ee7c6d-d727-4286-a127-42804d0d1082',
#                            'last_modified': None,
#                            'mimetype': None,
#                            'mimetype_inner': None,
#                            'name': 'Ensino Superior (pontos) - público e '
#                                    'privado',
#                            'package_id': '6ebbbf72-80bd-4b0e-b863-e22286f2919f',
#                            'position': 6,
#                            'resource_type': None,
#                            'revision_id': 'd4225254-7b89-42c4-9220-b1d17e88a93d',
#                            'size': None,
#                            'state': 'active',
#                            'url': 'https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/69',
#                            'url_type': None},
#                           {'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-03-30T02:14:52.924598',
#                            'datastore_active': False,
#                            'description': 'Ensino Superior (edificado) - '
#                                           'público e privado',
#                            'format': 'Esri REST',
#                            'hash': '',
#                            'id': '2cfe8f99-5ff7-43d6-b3ee-82ec0dc33a73',
#                            'last_modified': None,
#                            'mimetype': None,
#                            'mimetype_inner': None,
#                            'name': 'Ensino Superior (edificado) - público e '
#                                    'privado',
#                            'package_id': '6ebbbf72-80bd-4b0e-b863-e22286f2919f',
#                            'position': 7,
#                            'resource_type': None,
#                            'revision_id': 'fab54661-2c48-4c71-986e-ce4769e18ea1',
#                            'size': None,
#                            'state': 'active',
#                            'url': 'https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/70',
#                            'url_type': None}],
#             'revision_id': 'fab54661-2c48-4c71-986e-ce4769e18ea1',
#             'state': 'active',
#             'tags': [{'display_name': 'SIG',
#                       'id': '0977f8ff-cbb6-40e7-b9e2-b13b6ddc05f2',
#                       'name': 'SIG',
#                       'state': 'active',
#                       'vocabulary_id': None},
#                      {'display_name': 'apd-auto-load',
#                       'id': '1763dc2f-b7dd-4668-a33e-2fad32774c0c',
#                       'name': 'apd-auto-load',
#                       'state': 'active',
#                       'vocabulary_id': None},
#                      {'display_name': 'dmpu',
#                       'id': 'a4fd95fc-8a22-4108-a2e1-ae437bc4c47d',
#                       'name': 'dmpu',
#                       'state': 'active',
#                       'vocabulary_id': None}],
#             'title': 'Estabelecimentos de Ensino por Ano letivo',
#             'type': 'dataset',
#             'url': None,
#             'version': None},
#  'success': True}

# %%
## Example of an API enpoint indexed by CKAN

import requests
url = "https://opendata.urbanplatform.portodigital.pt/api/3/action/package_show?id=porto-meteorologia"
r = requests.get(url)
j = r.json()
for resource in j['result']['resources']:
  print("{}({}):".format(resource['name'], resource['format']))
  print(resource['url'] + "\n")
# Out:
# PORTO Meteorologia - Valores observados(fiware-ngsi):
# https://broker.fiware.urbanplatform.portodigital.pt/v2/entities?type=WeatherObserved
#
# PORTO Meteorologia - Previsão(fiware-ngsi):
# https://broker.fiware.urbanplatform.portodigital.pt/v2/entities?type=WeatherForecast

# %% [markdown]
# # IoT Data
#
# A special resource is the information from the IoT platform, which is accessible through the NGSI API. The historical data for each is available at a seperate endpoint.
#
# **Types**: Are types of devices or data \\
# **Entities**: Each entity is a device of a certain type
#
# **API documentation**
# * NGIS: https://fiware-orion.readthedocs.io/en/2.0.0/user/walkthrough_apiv2/#query-entity
# * Data format: https://gitlab.com/synchronicity-iot/synchronicity-data-models/
# * Historical data: http://history-data.urbanplatform.portodigital.pt/v2/ui/
#
# **API endpoints**
# * Live Data:  https://broker.fiware.urbanplatform.portodigital.pt/v2/
# * Historical Data: http://history-data.urbanplatform.portodigital.pt/v2/

# %%
## List of all IoT resources with the respective data type

import requests
import json

url = "https://broker.fiware.urbanplatform.portodigital.pt/v2/types"
r = requests.get(url)
j = r.json()

for item in j:
  print("{} ({}):".format(item["type"], item["count"]))
  attrs = item['attrs']
  print("{:<30} {:<15}".format('Name','Types'))
  for k, v in attrs.items():
    print("{:<30} {:<15}".format(k, ", ".join(v['types'])))
  print("")
# Out:
# AirQualityObserved (5):
# Name                           Types
# CO                             Number
# NO2                            Number
# O3                             Number
# Ox                             Number
# PM1                            Number
# PM10                           Number
# PM25                           Number
# dateObserved                   DateTime
# location                       geo:json
#
# ArrivalEstimation (8):
# Name                           Types
# dateModified                   DateTime
# description                    Text
# headSign                       StructuredValue
# remainingTime                  StructuredValue
#
# Device (191):
# Name                           Types
# category                       StructuredValue
# configuration                  StructuredValue
# controlledAsset                StructuredValue
# controlledProperty             StructuredValue
# dateExpires                    DateTime
# dateModified                   DateTime
# description                    None, Text
# l_serialNumber                 None, Text
# location                       None, geo:json
# name                           Text
# owner                          StructuredValue
# value                          Text
#
# Event (6202):
# Name                           Types
# address                        StructuredValue
# dateModified                   Text
# description                    Text
# description_es                 Text
# description_pt                 Text
# discounts                      Text
# discounts_es                   Text
# discounts_pt                   Text
# endDate                        StructuredValue, Text
# informationUrl                 Text
# informationUrl_es              Text
# informationUrl_pt              Text
# location                       Text, geo:json
# multimedia                     StructuredValue, Text
# name                           Text
# name_es                        Text
# name_pt                        Text
# observations                   Text
# observations_es                Text
# observations_pt                Text
# promoter                       Text
# promoter_es                    Text
# promoter_pt                    Text
# reservationUrl                 Text
# reservationUrl_es              Text
# reservationUrl_pt              Text
# schedule                       Text
# schedule_es                    Text
# schedule_pt                    Text
# specifications                 Text
# specifications_es              Text
# specifications_pt              Text
# startDate                      Text
# target                         Text
# target_es                      Text
# target_pt                      Text
# theme                          StructuredValue, Text
# theme_es                       StructuredValue, Text
# theme_pt                       StructuredValue, Text
#
# GtfsTransitFeedFile (1):
# Name                           Types
# description                    Text
# endDate                        Text
# feedFileURL                    Text
# publisher                      StructuredValue
# startDate                      Text
# version                        StructuredValue
#
# NoiseLevelObserved (15):
# Name                           Types
# LAeq                           Number
# dateObserved                   DateTime
# dateObservedFrom               DateTime
# dateObservedTo                 DateTime
# location                       geo:json
# measurand                      StructuredValue
#
# OffStreetParking (1):
# Name                           Types
# allowedVehicleType             StructuredValue
# availableSpotNumber            Number
# category                       StructuredValue
# chargeType                     StructuredValue
# location                       StructuredValue
# name                           Text
# occupancyDetectionType         StructuredValue
# requiredPermit                 StructuredValue
# totalSpotNumber                Number
#
# PointOfInterest (3060):
# Name                           Types
# accessibility                  None, StructuredValue, Text
# accessibility_es               None, StructuredValue, Text
# accessibility_pt               None, StructuredValue, Text
# address                        StructuredValue
# category                       StructuredValue
# closedOnHoliday                Text
# contactPoint                   StructuredValue
# costDescription                Text
# costDescription_es             Text
# costDescription_pt             Text
# dateModified                   DateTime, Text
# description                    None, Text
# description_es                 None, Text
# description_pt                 None, Text
# internetAccess                 None, Text
# internetWireless               None, Text
# location                       StructuredValue, Text, geo:json
# multimedia                     StructuredValue
# name                           Text
# name_es                        Text
# name_pt                        Text
# openingHoursSpecification      StructuredValue
# smokingArea                    None, Text
# socialNetwork                  StructuredValue, Text
# tag                            None, StructuredValue, Text
# tag_es                         None, StructuredValue, Text
# tag_pt                         None, StructuredValue, Text
# target                         StructuredValue, Text
# target_es                      StructuredValue, Text
# target_pt                      StructuredValue, Text
# touristic                      Text
# wifi                           None, Text
#
# TrafficFlowObserved (115):
# Name                           Types
# dateModified                   DateTime, Text
# dateObserved                   Text
# dateObservedFrom               DateTime, Text
# dateObservedTo                 DateTime, Text
# intensity                      Number
# laneId                         Number
# location                       geo:json
#
# Vehicle (246):
# Name                           Types
# category                       StructuredValue
# dateModified                   DateTime, Text
# latitude                       Number
# location                       geo:json
# longitude                      Number
# speed                          Number
# vehicleType                    Text
#
# WeatherForecast (131):
# Name                           Types
# address                        PostalAddress
# dataProvider                   Text
# dateIssued                     DateTime
# dateRetrieved                  DateTime
# dayMaximum                     StructuredValue
# dayMinimum                     StructuredValue
# feelsLikeTemperature           None, Number
# location                       geo:json
# precipitationProbability       None, Number
# relativeHumidity               None, Number
# source                         URL
# temperature                    None, Number
# validFrom                      DateTime
# validTo                        DateTime
# validity                       Text
# weatherType                    Text
# windDirection                  Number
# windSpeed                      None, Number
#
# WeatherObserved (17):
# Name                           Types
# PM1                            Number
# PM10                           Number
# PM25                           Number
# barometricPressure             Float, Number
# dataProvider                   String
# dateObserved                   DateTime
# dewPoint                       Number
# location                       geo:json
# name                           String
# precipitation                  Float
# relativeHumidity               Number
# solarRadiation                 Number
# source                         url
# temperature                    Number
# windDirection                  Float, Number
# windSpeed                      Float, Number
#
# gtfsAgency (1):
# Name                           Types
# language                       Text
# name                           Text
# page                           Text
# timezone                       Text
#
# gtfsCalendarDateRule (6):
# Name                           Types
# appliesOn                      Text
# exceptionType                  Text
# hasService                     Text
#
# gtfsCalendarRule (15):
# Name                           Types
# endDate                        Text
# friday                         Boolean
# hasService                     Text
# monday                         Boolean
# saturday                       Boolean
# startDate                      Text
# sunday                         Boolean
# thursday                       Boolean
# tuesday                        Boolean
# wednesday                      Boolean
#
# gtfsRoute (73):
# Name                           Types
# description                    Text
# name                           Text
# page                           Text
# routeColor                     Text
# routeID                        Text
# routeTextColor                 Text
# routeType                      Text
# shortName                      Text
#
# gtfsService (15):
# Name                           Types
# code                           Text
# operatedBy                     Text
#
# gtfsStop (2468):
# Name                           Types
# code                           Text
# location                       geo:json
# name                           Text
# page                           Text
# zoneCode                       Text

# %% [markdown]
# ## Accessing Live Value
# All the live value are available through the FiWare broker, as described in the documentation of the link on top. The example below ilustrates how to access all entities (an entity is a single sensor) of a certain type.

# %%
## You can access live values through the fiware broker

import requests
import pprint
url = "https://broker.fiware.urbanplatform.portodigital.pt/v2/entities?type=AirQualityObserved"
r = requests.get(url)
j = r.json()
pprint.pprint(j)
# Out:
# [{'CO': {'metadata': {}, 'type': 'Number', 'value': 760.9},
#   'NO2': {'metadata': {}, 'type': 'Number', 'value': 122.4},
#   'O3': {'metadata': {}, 'type': 'Number', 'value': 8.8},
#   'Ox': {'metadata': {}, 'type': 'Number', 'value': 133.6},
#   'PM1': {'metadata': {}, 'type': 'Number', 'value': 0},
#   'PM10': {'metadata': {}, 'type': 'Number', 'value': 0},
#   'PM25': {'metadata': {}, 'type': 'Number', 'value': 0},
#   'dateObserved': {'metadata': {},
#                    'type': 'DateTime',
#                    'value': '2019-03-29T19:02:21.00Z'},
#   'id': 'urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5adf39366f555a4514e7ea54',
#   'location': {'metadata': {},
#                'type': 'geo:json',
#                'value': {'coordinates': [-8.684325, 41.1735278],
#                          'crs': {'properties': {'name': 'EPSG:4326'},
#                                  'type': 'name'},
#                          'type': 'Point'}},
#   'type': 'AirQualityObserved'},
#  {'CO': {'metadata': {}, 'type': 'Number', 'value': 770.9},
#   'NO2': {'metadata': {}, 'type': 'Number', 'value': 81.1},
#   'O3': {'metadata': {}, 'type': 'Number', 'value': 28.1},
#   'Ox': {'metadata': {}, 'type': 'Number', 'value': 111.9},
#   'PM1': {'metadata': {}, 'type': 'Number', 'value': 3.8},
#   'PM10': {'metadata': {}, 'type': 'Number', 'value': 5.2},
#   'PM25': {'metadata': {}, 'type': 'Number', 'value': 3.8},
#   'dateObserved': {'metadata': {},
#                    'type': 'DateTime',
#                    'value': '2019-03-29T19:02:26.00Z'},
#   'id': 'urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5b97a1bde521e3053085c08c',
#   'location': {'metadata': {},
#                'type': 'geo:json',
#                'value': {'coordinates': [-8.605194, 41.180222],
#                          'crs': {'properties': {'name': 'EPSG:4326'},
#                                  'type': 'name'},
#                          'type': 'Point'}},
#   'type': 'AirQualityObserved'},
#  {'CO': {'metadata': {}, 'type': 'Number', 'value': 628.3},
#   'NO2': {'metadata': {}, 'type': 'Number', 'value': 68.9},
#   'O3': {'metadata': {}, 'type': 'Number', 'value': 63.4},
#   'Ox': {'metadata': {}, 'type': 'Number', 'value': 135.3},
#   'PM1': {'metadata': {}, 'type': 'Number', 'value': 4.8},
#   'PM10': {'metadata': {}, 'type': 'Number', 'value': 5.9},
#   'PM25': {'metadata': {}, 'type': 'Number', 'value': 4.3},
#   'dateObserved': {'metadata': {},
#                    'type': 'DateTime',
#                    'value': '2019-03-29T19:04:27.00Z'},
#   'id': 'urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5b632f2706599b05e998bed8',
#   'location': {'metadata': {},
#                'type': 'geo:json',
#                'value': {'coordinates': [-8.6721462, 41.165162],
#                          'crs': {'properties': {'name': 'EPSG:4326'},
#                                  'type': 'name'},
#                          'type': 'Point'}},
#   'type': 'AirQualityObserved'},
#  {'CO': {'metadata': {}, 'type': 'Number', 'value': 732.6},
#   'NO2': {'metadata': {}, 'type': 'Number', 'value': 100.8},
#   'O3': {'metadata': {}, 'type': 'Number', 'value': 35.4},
#   'Ox': {'metadata': {}, 'type': 'Number', 'value': 140},
#   'PM1': {'metadata': {}, 'type': 'Number', 'value': 4.6},
#   'PM10': {'metadata': {}, 'type': 'Number', 'value': 6.2},
#   'PM25': {'metadata': {}, 'type': 'Number', 'value': 4.6},
#   'dateObserved': {'metadata': {},
#                    'type': 'DateTime',
#                    'value': '2019-03-29T19:02:18.00Z'},
#   'id': 'urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5b72dbfa06599b05e9a74f27',
#   'location': {'metadata': {},
#                'type': 'geo:json',
#                'value': {'coordinates': [-8.5907964, 41.1625965],
#                          'crs': {'properties': {'name': 'EPSG:4326'},
#                                  'type': 'name'},
#                          'type': 'Point'}},
#   'type': 'AirQualityObserved'},
#  {'CO': {'metadata': {}, 'type': 'Number', 'value': 595.5},
#   'NO2': {'metadata': {}, 'type': 'Number', 'value': 54.5},
#   'O3': {'metadata': {}, 'type': 'Number', 'value': 45.4},
#   'Ox': {'metadata': {}, 'type': 'Number', 'value': 102.3},
#   'PM1': {'metadata': {}, 'type': 'Number', 'value': 5.9},
#   'PM10': {'metadata': {}, 'type': 'Number', 'value': 7.5},
#   'PM25': {'metadata': {}, 'type': 'Number', 'value': 5},
#   'dateObserved': {'metadata': {},
#                    'type': 'DateTime',
#                    'value': '2019-03-29T19:02:23.00Z'},
#   'id': 'urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5b97a1a6e521e3053085c067',
#   'location': {'metadata': {},
#                'type': 'geo:json',
#                'value': {'coordinates': [-8.6131861, 41.1718621],
#                          'crs': {'properties': {'name': 'EPSG:4326'},
#                                  'type': 'name'},
#                          'type': 'Point'}},
#   'type': 'AirQualityObserved'}]

# %% [markdown]
# ## Accessing historical values
# The historical values are accessible through the documentation described above. Because the query is quite heavy, you can only access one entity at once. \\
# In the example below we took the id of the first entity of the query above. \\
# Please note: The API automatically limits the number of records, and you will need to query more using the starting and ending date (see the full documentation on the link above).

# %%
## Example of IoT Resource - Air Quality

import requests
import pprint
url = "http://history-data.urbanplatform.portodigital.pt/v2/entities/urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5adf39366f555a4514e7ea54?limit=20"
r = requests.get(url)
j = r.json()
pprint.pprint(j)
# Out:
# {'data': {'attributes': [{'attrName': 'CO',
#                           'values': [461.7,
#                                      461.7,
#                                      353.2,
#                                      353.2,
#                                      353.2,
#                                      446.0,
#                                      446.0,
#                                      446.0,
#                                      355.0,
#                                      355.0,
#                                      355.0,
#                                      419.3,
#                                      419.3,
#                                      419.3,
#                                      293.4,
#                                      293.4,
#                                      293.4,
#                                      359.1,
#                                      359.1,
#                                      359.1]},
#                          {'attrName': 'NO2',
#                           'values': [110.2,
#                                      110.2,
#                                      97.3,
#                                      97.3,
#                                      97.3,
#                                      83.5,
#                                      83.5,
#                                      83.5,
#                                      85.7,
#                                      85.7,
#                                      85.7,
#                                      87.6,
#                                      87.6,
#                                      87.6,
#                                      64.5,
#                                      64.5,
#                                      64.5,
#                                      69.7,
#                                      69.7,
#                                      69.7]},
#                          {'attrName': 'O3',
#                           'values': [6.8,
#                                      6.8,
#                                      12.3,
#                                      12.3,
#                                      12.3,
#                                      20.1,
#                                      20.1,
#                                      20.1,
#                                      20.0,
#                                      20.0,
#                                      20.0,
#                                      21.1,
#                                      21.1,
#                                      21.1,
#                                      31.7,
#                                      31.7,
#                                      31.7,
#                                      29.1,
#                                      29.1,
#                                      29.1]},
#                          {'attrName': 'Ox',
#                           'values': [120.8,
#                                      120.8,
#                                      112.8,
#                                      112.8,
#                                      112.8,
#                                      107.2,
#                                      107.2,
#                                      107.2,
#                                      109.4,
#                                      109.4,
#                                      109.4,
#                                      112.5,
#                                      112.5,
#                                      112.5,
#                                      99.0,
#                                      99.0,
#                                      99.0,
#                                      101.8,
#                                      101.8,
#                                      101.8]},
#                          {'attrName': 'PM1',
#                           'values': [20.0,
#                                      19.8,
#                                      22.2,
#                                      22.8,
#                                      21.6,
#                                      19.2,
#                                      18.8,
#                                      18.4,
#                                      16.8,
#                                      18.6,
#                                      17.8,
#                                      15.6,
#                                      18.8,
#                                      19.0,
#                                      18.8,
#                                      17.8,
#                                      16.8,
#                                      16.6,
#                                      16.2,
#                                      17.0]},
#                          {'attrName': 'PM10',
#                           'values': [67.3,
#                                      70.4,
#                                      69.5,
#                                      73.7,
#                                      83.6,
#                                      60.5,
#                                      66.0,
#                                      66.0,
#                                      59.4,
#                                      58.5,
#                                      64.9,
#                                      52.8,
#                                      74.8,
#                                      74.4,
#                                      61.0,
#                                      61.6,
#                                      51.1,
#                                      63.4,
#                                      60.0,
#                                      50.6]},
#                          {'attrName': 'PM25',
#                           'values': [50.0,
#                                      49.5,
#                                      54.4,
#                                      56.0,
#                                      53.6,
#                                      48.5,
#                                      47.0,
#                                      45.6,
#                                      42.4,
#                                      45.6,
#                                      45.0,
#                                      39.6,
#                                      46.0,
#                                      46.8,
#                                      46.5,
#                                      44.4,
#                                      41.5,
#                                      41.6,
#                                      40.5,
#                                      42.0]},
#                          {'attrName': 'dateObserved',
#                           'values': ['2018-06-29T19:02:41.000',
#                                      '2018-06-29T19:07:13.000',
#                                      '2018-06-29T19:12:45.000',
#                                      '2018-06-29T19:17:17.000',
#                                      '2018-06-29T19:22:49.000',
#                                      '2018-06-29T19:27:21.000',
#                                      '2018-06-29T19:31:53.000',
#                                      '2018-06-29T19:37:25.000',
#                                      '2018-06-29T19:41:57.000',
#                                      '2018-06-29T19:47:29.000',
#                                      '2018-06-29T19:52:01.000',
#                                      '2018-06-29T19:57:33.000',
#                                      '2018-06-29T20:02:05.000',
#                                      '2018-06-29T20:07:37.000',
#                                      '2018-06-29T20:12:09.000',
#                                      '2018-06-29T20:17:41.000',
#                                      '2018-06-29T20:22:13.000',
#                                      '2018-06-29T20:27:45.000',
#                                      '2018-06-29T20:32:17.000',
#                                      '2018-06-29T20:37:49.000']},
#                          {'attrName': 'location',
#                           'values': [{'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'},
#                                      {'coordinates': [-8.598367008,
#                                                       41.148384191],
#                                       'crs': {'properties': {'name': 'EPSG:4326'},
#                                               'type': 'name'},
#                                       'type': 'Point'}]}],
#           'entityId': 'urn:ngsi-ld:AirQualityObserved:porto:environment:ubiwhere:5adf39366f555a4514e7ea54',
#           'index': ['2018-06-29T19:07:02.985',
#                     '2018-06-29T19:11:06.452',
#                     '2018-06-29T19:17:03.710',
#                     '2018-06-29T19:21:07.191',
#                     '2018-06-29T19:27:04.308',
#                     '2018-06-29T19:31:07.855',
#                     '2018-06-29T19:36:11.239',
#                     '2018-06-29T19:42:04.805',
#                     '2018-06-29T19:46:08.141',
#                     '2018-06-29T19:52:05.531',
#                     '2018-06-29T19:56:07.987',
#                     '2018-06-29T20:02:05.749',
#                     '2018-06-29T20:06:08.375',
#                     '2018-06-29T20:12:06.279',
#                     '2018-06-29T20:16:09.067',
#                     '2018-06-29T20:22:06.801',
#                     '2018-06-29T20:26:10.089',
#                     '2018-06-29T20:32:07.567',
#                     '2018-06-29T20:36:10.506',
#                     '2018-06-29T20:42:07.934']}}

# %% [markdown]
# # MIP Web
#
# The final resource is the MIP, which is the API of the city hall that has geographical data. Each dataset has a query builder, which you can experiment with. It is accessible by the URL and on the bottom of the page you can click “query”. All the queries must have at least the “where” parameter set, which works just like a postgresql query.
#
# Example: [http://mipweb.cm-porto.pt/arcgis/rest/services/APD/OpenData_APD/MapServer/13](http://mipweb.cm-porto.pt/arcgis/rest/services/APD/OpenData_APD/MapServer/13)

# %%
import json
import requests
import pprint


req_params = {
    'f': 'json',
    'where': "1=1",                        # 'where' clause is mandatory it takes a postgres-like query
    #'where': "n_o > 10",                  # example where the number of reports event was over 10
    #'where': "freguesia = 'Bonfim'",      # example for all the reports in 'Bonfim'
    #'where': "ano > 2000",                # Caveat: For example in this dataset, this will not work as 'ano' is defined as "esriFieldTypeString"
    'returnGeometry': 'true',
    'outFields': '*',                      # the fields that you want returned
    'orderByFields': 'objectid ASC', 
    #'resultOffset': '4000',
    #'resultRecordCount': '1000',
    'outSR': '4326',
    #'token': str(TOKEN) 
}
  
url = 'https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/63/query'
r = requests.get(url, params = req_params)
data = r.json()

for myItem in data['features']:
  myItemAttributes = myItem['attributes']
  pprint.pprint(myItemAttributes)
# Out:
# {'agr': 'Dr. Leonardo Coimbra Filho',
#  'cantina': 0,
#  'carto_1000': 'C5',
#  'cod_freg': '06',
#  'cod_giase': 1312897,
#  'cod_gis': '06170200003',
#  'cod_sgr': '1702',
#  'cod_topo': 'LPVAR0',
#  'cp_3': 622,
#  'cp_4': 4150,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Condominhas',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvrnqrg8bx9b&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23022184&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': 'info@eb1-porto-n32.rcts.pt',
#  'n_eb1': 34,
#  'n_ordem': '00003',
#  'n_policia': ' ',
#  'n_prim': 89,
#  'objectid': 1,
#  'planta': 'PLANTA\\CONDOMINHAS_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1',
#  'telf': 226171505,
#  'url': 'www.eb1-porto-n34.rcts.pt/',
#  'user_reg': 'josepaulo'}
# {'agr': 'Dr. Leonardo Coimbra Filho',
#  'cantina': 0,
#  'carto_1000': 'D4',
#  'cod_freg': '06',
#  'cod_giase': 1312023,
#  'cod_gis': '06170200004',
#  'cod_sgr': '1702',
#  'cod_topo': 'RJRCA0',
#  'cp_3': 434,
#  'cp_4': 4150,
#  'data_reg': 1245628800000,
#  'descricao': 'Bairro Marechal Gomes da Costa',
#  'designacao': 'Pasteleira',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvs6zrg8bgd9&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23022177&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': 'info@eb1-porto-n46.rcts.pt\r\n',
#  'n_eb1': 46,
#  'n_ordem': '00004',
#  'n_policia': ' ',
#  'n_prim': 115,
#  'objectid': 2,
#  'planta': 'PLANTA\\PASTELEIRA_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 226183554,
#  'url': 'www.eb1-porto-n46.rcts.pt/',
#  'user_reg': 'josepaulo'}
# {'agr': 'Dr. Leonardo Coimbra Filho',
#  'cantina': 0,
#  'carto_1000': 'C6',
#  'cod_freg': '06',
#  'cod_giase': 1312613,
#  'cod_gis': '06170200007',
#  'cod_sgr': '1702',
#  'cod_topo': 'RALEI1',
#  'cp_3': 105,
#  'cp_4': 4150,
#  'data_reg': 1245628800000,
#  'descricao': 'Bairro do Aleixo',
#  'designacao': 'Aleixo',
#  'est': 'Desactivo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'www.bing.com/maps/default.aspx?v=2&FORM=LMLTCP&cp=qvrnsmg8cg5y&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23022260&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 56,
#  'n_ordem': '00007',
#  'n_policia': ' ',
#  'n_prim': 150,
#  'objectid': 3,
#  'planta': 'PLANTA\\AINDA_NAO_DISPONIVEL.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 0,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Dr. Leonardo Coimbra Filho',
#  'cantina': 0,
#  'carto_1000': 'C5',
#  'cod_freg': '06',
#  'cod_giase': 1312365,
#  'cod_gis': '06170200008',
#  'cod_sgr': '1702',
#  'cod_topo': 'RESPO0',
#  'cp_3': 301,
#  'cp_4': 4150,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Lordelo do Ouro',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvrr5zg8byjp&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23022251&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': 'ji.estoril@eb23-dr-leonardo-coimbra.rcts.pt',
#  'n_eb1': 0,
#  'n_ordem': '00008',
#  'n_policia': ' ',
#  'n_prim': 0,
#  'objectid': 4,
#  'planta': 'PLANTA\\AINDA_NAO_DISPONIVEL.pdf',
#  'prop': ' ',
#  't_inst': 'JI',
#  'telf': 226171451,
#  'url': 'www.leonardocoimbra.net/',
#  'user_reg': 'josepaulo'}
# {'agr': 'Antas',
#  'cantina': 0,
#  'carto_1000': 'G12',
#  'cod_freg': '03',
#  'cod_giase': 1312594,
#  'cod_gis': '03170200001',
#  'cod_sgr': '1702',
#  'cod_topo': 'RALCA0',
#  'cp_3': 23,
#  'cp_4': 4350,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Montebello',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvvphcg8j500&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23032321&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': ' ',
#  'n_eb1': 15,
#  'n_ordem': '00001',
#  'n_policia': '322',
#  'n_prim': 34,
#  'objectid': 5,
#  'planta': 'PLANTA\\MONTEBELLO_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1',
#  'telf': 225020208,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Manoel de Oliveira',
#  'cantina': 0,
#  'carto_1000': 'G4',
#  'cod_freg': '01',
#  'cod_giase': 1312155,
#  'cod_gis': '01170200002',
#  'cod_sgr': '1702',
#  'cod_topo': 'RANGO0',
#  'cp_3': 58,
#  'cp_4': 4100,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Aldoar',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvvknng8bd3h&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23019861&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 0,
#  'n_ordem': '00002',
#  'n_policia': ' ',
#  'n_prim': 0,
#  'objectid': 6,
#  'planta': 'PLANTA\\AINDA_NAO_DISPONIVEL.pdf',
#  'prop': ' ',
#  't_inst': 'JI',
#  'telf': 226186971,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Manoel de Oliveira',
#  'cantina': 0,
#  'carto_1000': 'G4',
#  'cod_freg': '01',
#  'cod_giase': 1312731,
#  'cod_gis': '01170200003',
#  'cod_sgr': '1702',
#  'cod_topo': 'RMACA0',
#  'cp_3': 315,
#  'cp_4': 4100,
#  'data_reg': 1245628800000,
#  'descricao': 'Bairro da Fonte da Moura',
#  'designacao': 'Fonte da Moura',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvvkd2g8bbdn&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23019937&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': ' ',
#  'n_eb1': 52,
#  'n_ordem': '00003',
#  'n_policia': '14',
#  'n_prim': 134,
#  'objectid': 7,
#  'planta': 'PLANTA\\FONTE_DA_MOURA_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1',
#  'telf': 226184682,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': ' ',
#  'cantina': 0,
#  'carto_1000': 'H3',
#  'cod_freg': '01',
#  'cod_giase': 0,
#  'cod_gis': '01170200004',
#  'cod_sgr': '1702',
#  'cod_topo': 'RVILA1',
#  'cp_3': 513,
#  'cp_4': 4100,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Escola EB1 nº 26',
#  'est': 'Desactivo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'www.bing.com/maps/default.aspx?v=2&FORM=LMLTCP&cp=qvvppxg89nhx&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23019873&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': ' ',
#  'n_eb1': 26,
#  'n_ordem': '00004',
#  'n_policia': '1150',
#  'n_prim': 69,
#  'objectid': 8,
#  'planta': 'PLANTA\\AINDA_NAO_DISPONIVEL.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1',
#  'telf': 0,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': ' ',
#  'cantina': 0,
#  'carto_1000': 'A9',
#  'cod_freg': '15',
#  'cod_giase': 0,
#  'cod_gis': '15170200003',
#  'cod_sgr': '1702',
#  'cod_topo': 'RSMIG0',
#  'cp_3': 560,
#  'cp_4': 4050,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Escola EB1 nº 19',
#  'est': 'Desactivo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'www.bing.com/maps/default.aspx?v=2&FORM=LMLTCP&cp=qvqkd1g8fsvm&style=b&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23042859&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': ' ',
#  'n_eb1': 0,
#  'n_ordem': '00003',
#  'n_policia': '13',
#  'n_prim': 43,
#  'objectid': 9,
#  'planta': 'PLANTA\\AINDA_NAO_DISPONIVEL.pdf',
#  'prop': 'Privada (Fernando Reis Lima)',
#  't_inst': 'EB1',
#  'telf': 0,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Amial',
#  'cantina': 0,
#  'carto_1000': 'I8',
#  'cod_freg': '10',
#  'cod_giase': 1312989,
#  'cod_gis': '10170200007',
#  'cod_sgr': '1702',
#  'cod_topo': 'RMIOS0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': 'Bairro do Amial',
#  'designacao': 'Miosótis',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvwg02g8ff6m&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23029178&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': ' ',
#  'n_eb1': 18,
#  'n_ordem': '00007',
#  'n_policia': ' ',
#  'n_prim': 41,
#  'objectid': 10,
#  'planta': 'PLANTA\\MIOSOTIS_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1',
#  'telf': 228327650,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Amial',
#  'cantina': 0,
#  'carto_1000': 'I9',
#  'cod_freg': '10',
#  'cod_giase': 1312364,
#  'cod_gis': '10170200008',
#  'cod_sgr': '1702',
#  'cod_topo': 'RRGRA0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': 'Bairro da Azenha',
#  'designacao': 'Azenha',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 228323732,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvwzwwg8g453&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23029142&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': ' ',
#  'n_eb1': 21,
#  'n_ordem': '00008',
#  'n_policia': ' ',
#  'n_prim': 47,
#  'objectid': 11,
#  'planta': 'PLANTA\\AZENHA_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1',
#  'telf': 228323732,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Amial',
#  'cantina': 0,
#  'carto_1000': 'I9',
#  'cod_freg': '10',
#  'cod_giase': 1312056,
#  'cod_gis': '10170200009',
#  'cod_sgr': '1702',
#  'cod_topo': 'AVCAB0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': 'Bairro de S. Tomé',
#  'designacao': 'S. Tomé',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvwmtcg8g432&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23029282&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 20,
#  'n_ordem': '00009',
#  'n_policia': ' ',
#  'n_prim': 46,
#  'objectid': 12,
#  'planta': 'PLANTA\\S_TOME_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 228323525,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Amial',
#  'cantina': 0,
#  'carto_1000': 'I10',
#  'cod_freg': '10',
#  'cod_giase': 1312701,
#  'cod_gis': '10170200010',
#  'cod_sgr': '1702',
#  'cod_topo': 'RAAMI0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': 'Bairro da Agra do Amial',
#  'designacao': 'Agra',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvwfmvg8g75m&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23029260&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 49,
#  'n_ordem': '00010',
#  'n_policia': ' ',
#  'n_prim': 123,
#  'objectid': 13,
#  'planta': 'PLANTA\\AGRA_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 225506017,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Gomes Teixeira',
#  'cantina': 0,
#  'carto_1000': 'C7',
#  'cod_freg': '07',
#  'cod_giase': 1312085,
#  'cod_gis': '07170200001',
#  'cod_sgr': '1702',
#  'cod_topo': 'RBVIA0',
#  'cp_3': 140,
#  'cp_4': 4150,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Gólgota',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvr8m0g8df4j&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23033518&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': ' ',
#  'n_eb1': 40,
#  'n_ordem': '00001',
#  'n_policia': '11',
#  'n_prim': 103,
#  'objectid': 14,
#  'planta': 'PLANTA\\GOLGOTA_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1',
#  'telf': 226099094,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Miragaia',
#  'cantina': 0,
#  'carto_1000': 'B8',
#  'cod_freg': '08',
#  'cod_giase': 0,
#  'cod_gis': '08170200001',
#  'cod_sgr': '1702',
#  'cod_topo': 'RBAND0',
#  'cp_3': 88,
#  'cp_4': 4050,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Miragaia',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvqr6rg8fczm&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23033918&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 0,
#  'n_ordem': '00001',
#  'n_policia': '32',
#  'n_prim': 0,
#  'objectid': 15,
#  'planta': 'PLANTA\\BANDEIRINHA_PLANTA.pdf',
#  'prop': ' ',
#  't_inst': 'JI',
#  'telf': 226094949,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Gomes Teixeira',
#  'cantina': 0,
#  'carto_1000': 'D7',
#  'cod_freg': '07',
#  'cod_giase': 1312684,
#  'cod_gis': '07170200002',
#  'cod_sgr': '1702',
#  'cod_topo': 'RBBOC0',
#  'cp_3': 122,
#  'cp_4': 4150,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Bom Sucesso',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvs3t8g8dsbc&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23033371&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': ' ',
#  'n_eb1': 38,
#  'n_ordem': '00002',
#  'n_policia': '68',
#  'n_prim': 97,
#  'objectid': 16,
#  'planta': 'PLANTA\\BOM_SUCESSO_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1',
#  'telf': 226001154,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Gomes Teixeira',
#  'cantina': 0,
#  'carto_1000': 'D7',
#  'cod_freg': '07',
#  'cod_giase': 0,
#  'cod_gis': '07170200003',
#  'cod_sgr': '1702',
#  'cod_topo': 'RBBOC0',
#  'cp_3': 122,
#  'cp_4': 4150,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Massarelos',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvs3t8g8dsbc&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23033371&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 0,
#  'n_ordem': '00003',
#  'n_policia': '68',
#  'n_prim': 0,
#  'objectid': 17,
#  'planta': 'PLANTA\\BOM_SUCESSO_PLANTA.pdf',
#  'prop': ' ',
#  't_inst': 'JI',
#  'telf': 226002340,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Gomes Teixeira',
#  'cantina': 0,
#  'carto_1000': 'C9',
#  'cod_freg': '15',
#  'cod_giase': 1312148,
#  'cod_gis': '15170200001',
#  'cod_sgr': '1702',
#  'cod_topo': 'PCALB0',
#  'cp_3': 157,
#  'cp_4': 4050,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Vitória',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvrc3mg8ftf6&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23033852&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 0,
#  'n_ordem': '00001',
#  'n_policia': '53',
#  'n_prim': 0,
#  'objectid': 18,
#  'planta': 'PLANTA\\AINDA_NAO_DISPONIVEL.pdf',
#  'prop': ' ',
#  't_inst': 'JI',
#  'telf': 222073566,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Viso',
#  'cantina': 0,
#  'carto_1000': 'G5',
#  'cod_freg': '11',
#  'cod_giase': 1312125,
#  'cod_gis': '11170200004',
#  'cod_sgr': '1702',
#  'cod_topo': 'RDEGA0',
#  'cp_3': 224,
#  'cp_4': 4100,
#  'data_reg': 1245628800000,
#  'descricao': 'Bairro Engº Arantes Oliveira (Bairro das Campinas)',
#  'designacao': 'Campinas',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvvmrqg8c0mx&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23021331&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 54,
#  'n_ordem': '00004',
#  'n_policia': ' ',
#  'n_prim': 145,
#  'objectid': 19,
#  'planta': 'PLANTA\\CAMPINAS_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 226173773,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Dr. Augusto César Pires de Lima',
#  'cantina': 0,
#  'carto_1000': 'B11',
#  'cod_freg': '02',
#  'cod_giase': 0,
#  'cod_gis': '02170200003',
#  'cod_sgr': '1702',
#  'cod_topo': 'CVQAG0',
#  'cp_3': 506,
#  'cp_4': 4300,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Campo 24 de Agosto',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 225102140,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvr60cg8h3f6&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23043332&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 1,
#  'n_ordem': '00003',
#  'n_policia': '294',
#  'n_prim': 1,
#  'objectid': 20,
#  'planta': 'PLANTA\\CAMPO_24_AGOSTO_PLANTA.pdf',
#  'prop': 'Junta de Freguesia do Bonfim',
#  't_inst': 'EB1/JI',
#  'telf': 225102140,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Dr. Augusto César Pires de Lima',
#  'cantina': 0,
#  'carto_1000': 'A10',
#  'cod_freg': '14',
#  'cod_giase': 1312396,
#  'cod_gis': '14170200001',
#  'cod_sgr': '1702',
#  'cod_topo': 'RSOL_0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Sé',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvqhcjg8gnhs&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23042873&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 25,
#  'n_ordem': '00001',
#  'n_policia': ' ',
#  'n_prim': 65,
#  'objectid': 21,
#  'planta': 'PLANTA\\SE_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 222059295,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Miragaia',
#  'cantina': 0,
#  'carto_1000': 'C9',
#  'cod_freg': '15',
#  'cod_giase': 1312920,
#  'cod_gis': '15170200002',
#  'cod_sgr': '1702',
#  'cod_topo': 'PCALB0',
#  'cp_3': 157,
#  'cp_4': 4050,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Carlos Alberto',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvrc3mg8ftf6&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23033852&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': ' ',
#  'n_eb1': 51,
#  'n_ordem': '00002',
#  'n_policia': '56',
#  'n_prim': 130,
#  'objectid': 22,
#  'planta': 'PLANTA\\CARLOS_ALBERTO_PLANTA.pdf',
#  'prop': 'Junta de Freguesia da Vitória',
#  't_inst': 'EB1',
#  'telf': 222050911,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Rodrigues de Freitas',
#  'cantina': 0,
#  'carto_1000': 'D8',
#  'cod_freg': '04',
#  'cod_giase': 1312199,
#  'cod_gis': '04170200002',
#  'cod_sgr': '1702',
#  'cod_topo': 'RICSM0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Torrinha',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvs2rkg8f6jr&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23033297&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 27,
#  'n_ordem': '00002',
#  'n_policia': ' ',
#  'n_prim': 71,
#  'objectid': 23,
#  'planta': 'PLANTA\\TORRINHA_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 226005993,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Miragaia',
#  'cantina': 0,
#  'carto_1000': 'B8',
#  'cod_freg': '08',
#  'cod_giase': 1312973,
#  'cod_gis': '08170200002',
#  'cod_sgr': '1702',
#  'cod_topo': 'RBAND0',
#  'cp_3': 88,
#  'cp_4': 4050,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Bandeirinha',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvqr6rg8fczm&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23033918&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': ' ',
#  'n_eb1': 42,
#  'n_ordem': '00002',
#  'n_policia': '32',
#  'n_prim': 107,
#  'objectid': 24,
#  'planta': 'PLANTA\\BANDEIRINHA_PLANTA.pdf',
#  'prop': 'Estado (Ex. Dir.do Distrito Escolar)',
#  't_inst': 'EB1',
#  'telf': 226094949,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Miragaia',
#  'cantina': 0,
#  'carto_1000': 'A9',
#  'cod_freg': '13',
#  'cod_giase': 1312405,
#  'cod_gis': '13170200001',
#  'cod_sgr': '1702',
#  'cod_topo': 'CFVEL0',
#  'cp_3': 271,
#  'cp_4': 4050,
#  'data_reg': 1245628800000,
#  'descricao': '(constituida por duas partes, 50-A e 50-B, ligadas por uma '
#               'passagem superior sobre o caminho público)',
#  'designacao': 'S. Nicolau',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvq4sbg8fpmt&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23042820&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 50,
#  'n_ordem': '00001',
#  'n_policia': '21',
#  'n_prim': 125,
#  'objectid': 25,
#  'planta': 'PLANTA\\AINDA_NAO_DISPONIVEL.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 222088091,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Dr. Leonardo Coimbra Filho',
#  'cantina': 0,
#  'carto_1000': 'D5',
#  'cod_freg': '06',
#  'cod_giase': 1312974,
#  'cod_gis': '06170200006',
#  'cod_sgr': '1702',
#  'cod_topo': 'RCOND0',
#  'cp_3': 221,
#  'cp_4': 4150,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Lordelo',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvs1k9g8cczk&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23022148&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': 'info@eb1-porto-n35.rcts.pt',
#  'n_eb1': 35,
#  'n_ordem': '00006',
#  'n_policia': '774',
#  'n_prim': 91,
#  'objectid': 26,
#  'planta': 'PLANTA\\LORDELO_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 226175457,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Antas',
#  'cantina': 0,
#  'carto_1000': 'E12',
#  'cod_freg': '03',
#  'cod_giase': 1312581,
#  'cod_gis': '03170200002',
#  'cod_sgr': '1702',
#  'cod_topo': 'RRALV0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Monte Aventino',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvt8xdg8j020&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23032208&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 22,
#  'n_ordem': '00002',
#  'n_policia': ' ',
#  'n_prim': 50,
#  'objectid': 27,
#  'planta': 'PLANTA\\MONTE_AVENTINO_PLANTA.pdf',
#  'prop': 'Estado (Ex. Dir.do Distrito Escolar)',
#  't_inst': 'EB1/JI',
#  'telf': 225020897,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Augusto Gil',
#  'cantina': 0,
#  'carto_1000': 'E11',
#  'cod_freg': '02',
#  'cod_giase': 0,
#  'cod_gis': '02170200001',
#  'cod_sgr': '1702',
#  'cod_topo': 'RSPOU0',
#  'cp_3': 490,
#  'cp_4': 4000,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Aurélia de Sousa',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvt3vjg8h26w&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23032221&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 0,
#  'n_ordem': '00001',
#  'n_policia': '1329',
#  'n_prim': 0,
#  'objectid': 28,
#  'planta': 'PLANTA\\AINDA_NAO_DISPONIVEL.pdf',
#  'prop': ' ',
#  't_inst': 'JI',
#  'telf': 225028858,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Dr. Augusto César Pires de Lima',
#  'cantina': 0,
#  'carto_1000': 'A11',
#  'cod_freg': '02',
#  'cod_giase': 1312354,
#  'cod_gis': '02170200002',
#  'cod_sgr': '1702',
#  'cod_topo': 'PALEG0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Alegria',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvqkbdg8h01r&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23043288&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 3,
#  'n_ordem': '00002',
#  'n_policia': ' ',
#  'n_prim': 6,
#  'objectid': 29,
#  'planta': 'PLANTA\\AINDA_NAO_DISPONIVEL.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 225364238,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Antas',
#  'cantina': 0,
#  'carto_1000': 'H13',
#  'cod_freg': '03',
#  'cod_giase': 1312013,
#  'cod_gis': '03170200003',
#  'cod_sgr': '1702',
#  'cod_topo': 'RSACO0',
#  'cp_3': 290,
#  'cp_4': 4350,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Dó-Ré-Mi II',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvw07xg8jctb&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23032299&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 0,
#  'n_ordem': '00003',
#  'n_policia': '573',
#  'n_prim': 0,
#  'objectid': 30,
#  'planta': 'PLANTA\\AINDA_NAO_DISPONIVEL.pdf',
#  'prop': ' ',
#  't_inst': 'JI',
#  'telf': 225029294,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Areosa',
#  'cantina': 0,
#  'carto_1000': 'I14',
#  'cod_freg': '03',
#  'cod_giase': 1312067,
#  'cod_gis': '03170200004',
#  'cod_sgr': '1702',
#  'cod_topo': 'RDBSJ0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': 'Bairro de S. João de Deus (até 2004 possuia também o 2º ciclo)',
#  'designacao': 'S. João de Deus',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvwph8g8k3q5&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23029996&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 58,
#  'n_ordem': '00004',
#  'n_policia': ' ',
#  'n_prim': 15,
#  'objectid': 31,
#  'planta': 'PLANTA\\S_JOAO_DE_DEUS_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 225407254,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Cerco',
#  'cantina': 0,
#  'carto_1000': 'E13',
#  'cod_freg': '03',
#  'cod_giase': 1312588,
#  'cod_gis': '03170200005',
#  'cod_sgr': '1702',
#  'cod_topo': 'RFALC0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Falcão',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvsv2qg8jwzh&style=b&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23034360&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 7,
#  'n_ordem': '00005',
#  'n_policia': ' ',
#  'n_prim': 17,
#  'objectid': 32,
#  'planta': 'PLANTA\\FALCAO_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 225365713,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Cerco',
#  'cantina': 0,
#  'carto_1000': 'E13',
#  'cod_freg': '03',
#  'cod_giase': 1312240,
#  'cod_gis': '03170200006',
#  'cod_sgr': '1702',
#  'cod_topo': 'RFALC0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Dó-Ré-Mi I',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvsxpmg8jwjm&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23034360&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 0,
#  'n_ordem': '00006',
#  'n_policia': ' ',
#  'n_prim': 0,
#  'objectid': 33,
#  'planta': 'PLANTA\\AINDA_NAO_DISPONIVEL.pdf',
#  'prop': ' ',
#  't_inst': 'JI',
#  'telf': 225370437,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Cerco',
#  'cantina': 0,
#  'carto_1000': 'D13',
#  'cod_freg': '03',
#  'cod_giase': 1312478,
#  'cod_gis': '03170200007',
#  'cod_sgr': '1702',
#  'cod_topo': 'PCORU0',
#  'cp_3': 144,
#  'cp_4': 4300,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Corujeira',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvscp8g8jjb8&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23034391&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 6,
#  'n_ordem': '00007',
#  'n_policia': '12',
#  'n_prim': 32,
#  'objectid': 34,
#  'planta': 'PLANTA\\CORUJEIRA_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 225374168,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Ramalho Ortigão',
#  'cantina': 0,
#  'carto_1000': 'B12',
#  'cod_freg': '02',
#  'cod_giase': 1312431,
#  'cod_gis': '02170200004',
#  'cod_sgr': '1702',
#  'cod_topo': 'RFHPI0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Lomba',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvr7ntg8hrms&style=b&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23034260&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 11,
#  'n_ordem': '00004',
#  'n_policia': ' ',
#  'n_prim': 27,
#  'objectid': 35,
#  'planta': 'PLANTA\\LOMBA_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 225100909,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Ramalho Ortigão',
#  'cantina': 0,
#  'carto_1000': 'D12',
#  'cod_freg': '03',
#  'cod_giase': 1312579,
#  'cod_gis': '03170200008',
#  'cod_sgr': '1702',
#  'cod_topo': 'RPEMO0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': '(vereda interior)',
#  'designacao': 'Flores',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvsc4rg8hs9s&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23034108&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 8,
#  'n_ordem': '00008',
#  'n_policia': ' ',
#  'n_prim': 19,
#  'objectid': 36,
#  'planta': 'PLANTA\\FLORES_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 225103226,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Ramalho Ortigão',
#  'cantina': 0,
#  'carto_1000': 'B12',
#  'cod_freg': '03',
#  'cod_giase': 1312413,
#  'cod_gis': '03170200009',
#  'cod_sgr': '1702',
#  'cod_topo': 'LNOED0',
#  'cp_3': 352,
#  'cp_4': 4300,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Noeda',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvqwkfg8j8rd&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23043109&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 14,
#  'n_ordem': '00009',
#  'n_policia': '6',
#  'n_prim': 33,
#  'objectid': 37,
#  'planta': 'PLANTA\\NOEDA_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 225362872,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Ramalho Ortigão',
#  'cantina': 0,
#  'carto_1000': 'C14',
#  'cod_freg': '03',
#  'cod_giase': 1312264,
#  'cod_gis': '03170200010',
#  'cod_sgr': '1702',
#  'cod_topo': 'RLAGA0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': 'Bairro do Lagarteiro',
#  'designacao': 'Lagarteiro',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvrzyfg8kbrp&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23034561&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 10,
#  'n_ordem': '00010',
#  'n_policia': ' ',
#  'n_prim': 24,
#  'objectid': 38,
#  'planta': 'PLANTA\\LAGARTEIRO_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 225303238,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Clara de Resende',
#  'cantina': 0,
#  'carto_1000': 'E7',
#  'cod_freg': '06',
#  'cod_giase': 1312819,
#  'cod_gis': '06170200001',
#  'cod_sgr': '1702',
#  'cod_topo': 'RJDEU0',
#  'cp_3': 461,
#  'cp_4': 4100,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'João de Deus',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 226064175,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvt8dvg8d3zp&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23031228&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': 'info@eb1-porto-n47.rcts.pt',
#  'n_eb1': 47,
#  'n_ordem': '00001',
#  'n_policia': '395',
#  'n_prim': 117,
#  'objectid': 39,
#  'planta': 'PLANTA\\JOAO_DE_DEUS_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1',
#  'telf': 226098182,
#  'url': 'www.eb1-porto-n47.rcts.pt/',
#  'user_reg': 'josepaulo'}
# {'agr': 'Maria Lamas',
#  'cantina': 0,
#  'carto_1000': 'F6',
#  'cod_freg': '11',
#  'cod_giase': 1312815,
#  'cod_gis': '11170200002',
#  'cod_sgr': '1702',
#  'cod_topo': 'RPAME0',
#  'cp_3': 45,
#  'cp_4': 4100,
#  'data_reg': 1245628800000,
#  'descricao': 'Bairro de Francos',
#  'designacao': 'Padre Américo',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvtzghg8d11s&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23031121&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': 'info@eb1-ji-n-45-porto.rcts.pt',
#  'n_eb1': 45,
#  'n_ordem': '00002',
#  'n_policia': ' ',
#  'n_prim': 114,
#  'objectid': 40,
#  'planta': 'PLANTA\\PADRE_AMERICO_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 226066212,
#  'url': 'www.eb1-ji-n-45-porto.rcts.pt/',
#  'user_reg': 'josepaulo'}
# {'agr': 'Francisco Torrinha',
#  'cantina': 0,
#  'carto_1000': 'E2',
#  'cod_freg': '09',
#  'cod_giase': 1312257,
#  'cod_gis': '09170200001',
#  'cod_sgr': '1702',
#  'cod_topo': 'RESCO1',
#  'cp_3': 299,
#  'cp_4': 4150,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'S. Miguel de Nevogilde',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvsypzg88zn6&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23022788&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': 'info@eb1-porto-n43.rcts.pt',
#  'n_eb1': 43,
#  'n_ordem': '00001',
#  'n_policia': '60',
#  'n_prim': 111,
#  'objectid': 41,
#  'planta': 'PLANTA\\S_MIGUEL_NEVOGILDE_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1',
#  'telf': 226184759,
#  'url': 'www.eb1-porto-n43.rcts.pt/',
#  'user_reg': 'josepaulo'}
# {'agr': 'Francisco Torrinha',
#  'cantina': 0,
#  'carto_1000': 'C3',
#  'cod_freg': '05',
#  'cod_giase': 1312501,
#  'cod_gis': '05170200001',
#  'cod_sgr': '1702',
#  'cod_topo': 'RHMOR0',
#  'cp_3': 397,
#  'cp_4': 4150,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'S. João da Foz',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvrrnwg89qws&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23022413&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': 'info@eb1-porto-n33.rcts.pt',
#  'n_eb1': 33,
#  'n_ordem': '00001',
#  'n_policia': ' ',
#  'n_prim': 88,
#  'objectid': 42,
#  'planta': 'PLANTA\\S_JOAO_DA_FOZ_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1',
#  'telf': 226154089,
#  'url': 'www.eb1-porto-n33.rcts.pt/',
#  'user_reg': 'josepaulo'}
# {'agr': 'Francisco Torrinha',
#  'cantina': 0,
#  'carto_1000': 'C4',
#  'cod_freg': '06',
#  'cod_giase': 1312751,
#  'cod_gis': '06170200002',
#  'cod_sgr': '1702',
#  'cod_topo': 'RPGAM0',
#  'cp_3': 589,
#  'cp_4': 4150,
#  'data_reg': 1245628800000,
#  'descricao': 'Bairro Rainha D. Leonor',
#  'designacao': 'Paulo da Gama',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvrhqvg8bdc0&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23022910&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': 'info@eb1-porto-n32.rcts.pt',
#  'n_eb1': 32,
#  'n_ordem': '00002',
#  'n_policia': ' ',
#  'n_prim': 86,
#  'objectid': 43,
#  'planta': 'PLANTA\\PAULO_DA_GAMA_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 226181620,
#  'url': 'www.eb1-porto-n32.rcts.pt/',
#  'user_reg': 'josepaulo'}
# {'agr': 'Dr. Augusto César Pires de Lima',
#  'cantina': 0,
#  'carto_1000': 'A10',
#  'cod_freg': '14',
#  'cod_giase': 0,
#  'cod_gis': '14170200002',
#  'cod_sgr': '1702',
#  'cod_topo': 'RSOL_0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Sé',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvqhcjg8gnhs&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23042873&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 0,
#  'n_ordem': '00002',
#  'n_policia': ' ',
#  'n_prim': 0,
#  'objectid': 44,
#  'planta': 'PLANTA\\SE_PLANTA.pdf',
#  'prop': ' ',
#  't_inst': 'JI',
#  'telf': 222059295,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Viso',
#  'cantina': 0,
#  'carto_1000': 'I6',
#  'cod_freg': '11',
#  'cod_giase': 1312122,
#  'cod_gis': '11170200005',
#  'cod_sgr': '1702',
#  'cod_topo': 'RBORD0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': 'Bairro do Viso',
#  'designacao': 'Viso',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvwr6zg8ck76&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23018608&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 37,
#  'n_ordem': '00005',
#  'n_policia': ' ',
#  'n_prim': 95,
#  'objectid': 45,
#  'planta': 'PLANTA\\VISO_PLANTA.pdf',
#  'prop': 'Estado (Ex. Dir.do Distrito Escolar)',
#  't_inst': 'EB1/JI',
#  'telf': 226160188,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Viso',
#  'cantina': 0,
#  'carto_1000': 'H6',
#  'cod_freg': '11',
#  'cod_giase': 1312096,
#  'cod_gis': '11170200006',
#  'cod_sgr': '1702',
#  'cod_topo': 'RCRUZ1',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Cruzes',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvw2ssg8cxpb&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23028814&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 44,
#  'n_ordem': '00006',
#  'n_policia': ' ',
#  'n_prim': 113,
#  'objectid': 46,
#  'planta': 'PLANTA\\CRUZES_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 226164770,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Viso',
#  'cantina': 0,
#  'carto_1000': 'G5',
#  'cod_freg': '11',
#  'cod_giase': 1312100,
#  'cod_gis': '11170200007',
#  'cod_sgr': '1702',
#  'cod_topo': 'AVGAM0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Ramalde',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvvfm0g8bx24&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23021331&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 0,
#  'n_ordem': '00007',
#  'n_policia': ' ',
#  'n_prim': 0,
#  'objectid': 47,
#  'planta': 'PLANTA\\AINDA_NAO_DISPONIVEL.pdf',
#  'prop': ' ',
#  't_inst': 'JI',
#  'telf': 226172814,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Cerco',
#  'cantina': 0,
#  'carto_1000': 'F13',
#  'cod_freg': '03',
#  'cod_giase': 1312780,
#  'cod_gis': '03170200013',
#  'cod_sgr': '1702',
#  'cod_topo': 'RSCAM0',
#  'cp_3': 320,
#  'cp_4': 4350,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Sra de Campanhã',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvttskg8jxty&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23033119&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 13,
#  'n_ordem': '00013',
#  'n_policia': ' ',
#  'n_prim': 31,
#  'objectid': 48,
#  'planta': 'PLANTA\\SRA_CAMPANHA_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 225371264,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Irene Lisboa',
#  'cantina': 0,
#  'carto_1000': 'D9',
#  'cod_freg': '04',
#  'cod_giase': 1312625,
#  'cod_gis': '04170200004',
#  'cod_sgr': '1702',
#  'cod_topo': 'RPLRO0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Miminho',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvsg93g8frpk&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23033691&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 0,
#  'n_ordem': '00004',
#  'n_policia': ' ',
#  'n_prim': 0,
#  'objectid': 49,
#  'planta': 'PLANTA\\AINDA_NAO_DISPONIVEL.pdf',
#  'prop': ' ',
#  't_inst': 'JI',
#  'telf': 223322158,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Francisco Torrinha',
#  'cantina': 0,
#  'carto_1000': 'E2',
#  'cod_freg': '09',
#  'cod_giase': 1312662,
#  'cod_gis': '09170200002',
#  'cod_sgr': '1702',
#  'cod_topo': 'RESCO1',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Nevogilde',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvsvbyg890pn&style=b&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23022814&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 0,
#  'n_ordem': '00002',
#  'n_policia': ' ',
#  'n_prim': 0,
#  'objectid': 50,
#  'planta': 'PLANTA\\AINDA_NAO_DISPONIVEL.pdf',
#  'prop': ' ',
#  't_inst': 'JI',
#  'telf': 226186888,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Francisco Torrinha',
#  'cantina': 0,
#  'carto_1000': 'C3',
#  'cod_freg': '05',
#  'cod_giase': 1312728,
#  'cod_gis': '05170200002',
#  'cod_sgr': '1702',
#  'cod_topo': 'RRBAI0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Foz do Douro',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvrvt7g89qzg&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23022433&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 0,
#  'n_ordem': '00002',
#  'n_policia': ' ',
#  'n_prim': 0,
#  'objectid': 51,
#  'planta': 'PLANTA\\AINDA_NAO_DISPONIVEL.pdf',
#  'prop': ' ',
#  't_inst': 'JI',
#  'telf': 226188872,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Viso',
#  'cantina': 0,
#  'carto_1000': 'I6',
#  'cod_freg': '11',
#  'cod_giase': 0,
#  'cod_gis': '11170200009',
#  'cod_sgr': '1702',
#  'cod_topo': 'RFCAS1',
#  'cp_3': 206,
#  'cp_4': 4250,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Ferreira de Castro',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'www.bing.com/maps/default.aspx?v=2&FORM=LMLTCP&cp=qvwg3vg8cq37&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23018579&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 0,
#  'n_ordem': '00009',
#  'n_policia': '90',
#  'n_prim': 0,
#  'objectid': 52,
#  'planta': 'PLANTA\\AINDA_NAO_DISPONIVEL.pdf',
#  'prop': ' ',
#  't_inst': 'JI',
#  'telf': 225320500,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Eugénio de Andrade',
#  'cantina': 0,
#  'carto_1000': 'G11',
#  'cod_freg': '10',
#  'cod_giase': 1312153,
#  'cod_gis': '10170200001',
#  'cod_sgr': '1702',
#  'cod_topo': 'RPCDM0',
#  'cp_3': 451,
#  'cp_4': 4200,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Augusto Lessa',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvvjqzg8h0m0&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23032022&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': 'eb1augustolessa@gmail.com',
#  'n_eb1': 16,
#  'n_ordem': '00001',
#  'n_policia': '11',
#  'n_prim': 35,
#  'objectid': 53,
#  'planta': 'PLANTA\\AUGUSTO_LESSA_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1',
#  'telf': 225502971,
#  'url': 'www.eb1-porto-n16.rcts.pt',
#  'user_reg': 'josepaulo'}
# {'agr': 'Irene Lisboa',
#  'cantina': 0,
#  'carto_1000': 'G9',
#  'cod_freg': '10',
#  'cod_giase': 1312903,
#  'cod_gis': '10170200004',
#  'cod_sgr': '1702',
#  'cod_topo': 'RARZI0',
#  'cp_3': 66,
#  'cp_4': 4250,
#  'data_reg': 1245628800000,
#  'descricao': 'Bairro do Bom Pastor',
#  'designacao': 'Bom Pastor',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvv8bwg8fwc2&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23031445&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': 'calm1974@iol.pt',
#  'n_eb1': 57,
#  'n_ordem': '00004',
#  'n_policia': ' ',
#  'n_prim': 151,
#  'objectid': 54,
#  'planta': 'PLANTA\\BOM_PASTOR_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 225025024,
#  'url': 'www.eb1-porto-n57.rcts.pt/',
#  'user_reg': 'josepaulo'}
# {'agr': 'Irene Lisboa',
#  'cantina': 0,
#  'carto_1000': 'F9',
#  'cod_freg': '10',
#  'cod_giase': 1312706,
#  'cod_gis': '10170200005',
#  'cod_sgr': '1702',
#  'cod_topo': 'RRSOU0',
#  'cp_3': 405,
#  'cp_4': 4250,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Ribeiro de Sousa',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvtwwmg8fyj8&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23031562&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': 'info@eb1-porto-n30.rcts.pt',
#  'n_eb1': 30,
#  'n_ordem': '00005',
#  'n_policia': ' ',
#  'n_prim': 79,
#  'objectid': 55,
#  'planta': 'PLANTA\\RIBEIRO_SOUSA_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 225096149,
#  'url': 'www.eb1-porto-n30.rcts.pt/',
#  'user_reg': 'josepaulo'}
# {'agr': 'Irene Lisboa',
#  'cantina': 0,
#  'carto_1000': 'F9',
#  'cod_freg': '04',
#  'cod_giase': 1312695,
#  'cod_gis': '04170200001',
#  'cod_sgr': '1702',
#  'cod_topo': 'RPJPM0',
#  'cp_3': 256,
#  'cp_4': 4250,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Constituição',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvtkbyg8fr49&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23031678&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': 'info@eb1-porto-n31.rcts.pt',
#  'n_eb1': 31,
#  'n_ordem': '00001',
#  'n_policia': '31',
#  'n_prim': 80,
#  'objectid': 56,
#  'planta': 'PLANTA\\CONSTITUIÇAO_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 228317761,
#  'url': 'www.eb1-porto-n31.rcts.pt/',
#  'user_reg': 'josepaulo'}
# {'agr': 'Eugénio de Andrade',
#  'cantina': 0,
#  'carto_1000': 'F10',
#  'cod_freg': '10',
#  'cod_giase': 1312325,
#  'cod_gis': '10170200003',
#  'cod_sgr': '1702',
#  'cod_topo': 'RDAPA0',
#  'cp_3': 0,
#  'cp_4': 4200,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Covelo',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvttp1g8g979&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23031690&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': 'info@eb1-porto-n28.rcts.pt',
#  'n_eb1': 28,
#  'n_ordem': '00003',
#  'n_policia': ' ',
#  'n_prim': 73,
#  'objectid': 57,
#  'planta': 'PLANTA\\COVELO_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 225511936,
#  'url': 'www.eb1-porto-n28.rcts.pt/',
#  'user_reg': 'josepaulo'}
# {'agr': 'Eugénio de Andrade',
#  'cantina': 0,
#  'carto_1000': 'F11',
#  'cod_freg': '10',
#  'cod_giase': 1312422,
#  'cod_gis': '10170200002',
#  'cod_sgr': '1702',
#  'cod_topo': 'RCCAB0',
#  'cp_3': 223,
#  'cp_4': 4200,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Costa Cabral',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvtypgg8h10c&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23032140&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': 'ecostacabral@gmail.com',
#  'n_eb1': 17,
#  'n_ordem': '00002',
#  'n_policia': '551',
#  'n_prim': 37,
#  'objectid': 58,
#  'planta': 'PLANTA\\COSTA_CABRAL_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1',
#  'telf': 225090497,
#  'url': 'www.eb1-porto-n17.rcts.pt',
#  'user_reg': 'josepaulo'}
# {'agr': 'Maria Lamas',
#  'cantina': 0,
#  'carto_1000': 'G8',
#  'cod_freg': '10',
#  'cod_giase': 1312757,
#  'cod_gis': '10170200006',
#  'cod_sgr': '1702',
#  'cod_topo': 'RSPIN1',
#  'cp_3': 481,
#  'cp_4': 4250,
#  'data_reg': 1245628800000,
#  'descricao': 'Bairro do Carvalhido',
#  'designacao': 'Caramila',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvv7z3g8f8mq&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23031439&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': 'info@eb1-porto-n41.rcts.pt',
#  'n_eb1': 41,
#  'n_ordem': '00006',
#  'n_policia': ' ',
#  'n_prim': 105,
#  'objectid': 59,
#  'planta': 'PLANTA\\CARAMILA_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 228320107,
#  'url': 'www.eb1-porto-n41.rcts.pt/',
#  'user_reg': 'josepaulo'}
# {'agr': 'Maria Lamas',
#  'cantina': 0,
#  'carto_1000': 'G7',
#  'cod_freg': '11',
#  'cod_giase': 1312092,
#  'cod_gis': '11170200001',
#  'cod_sgr': '1702',
#  'cod_topo': 'RCGUI0',
#  'cp_3': 108,
#  'cp_4': 4250,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Castelos',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvvdw0g8dtjm&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23031022&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': 'castelos@agrup-mlamas.pt',
#  'n_eb1': 29,
#  'n_ordem': '00001',
#  'n_policia': '218',
#  'n_prim': 75,
#  'objectid': 60,
#  'planta': 'PLANTA\\CASTELOS_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 228313595,
#  'url': 'www.eb1-porto-n29.rcts.pt/',
#  'user_reg': 'josepaulo'}
# {'agr': 'Viso',
#  'cantina': 0,
#  'carto_1000': 'H4',
#  'cod_freg': '11',
#  'cod_giase': 1312383,
#  'cod_gis': '11170200003',
#  'cod_sgr': '1702',
#  'cod_topo': 'RCHOU0',
#  'cp_3': 160,
#  'cp_4': 4100,
#  'data_reg': 1245628800000,
#  'descricao': 'Bairro de Pereiró',
#  'designacao': 'Correios',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvvyxjg8bmm0&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23021389&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 48,
#  'n_ordem': '00003',
#  'n_policia': ' ',
#  'n_prim': 119,
#  'objectid': 61,
#  'planta': 'PLANTA\\CORREIOS_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 226102458,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Augusto Gil',
#  'cantina': 0,
#  'carto_1000': 'E10',
#  'cod_freg': '12',
#  'cod_giase': 1312308,
#  'cod_gis': '12170200001',
#  'cod_sgr': '1702',
#  'cod_topo': 'TCAMP0',
#  'cp_3': 153,
#  'cp_4': 4000,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'José Gomes Ferreira',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 225097623,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvsxf5g8gh4x&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23031785&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': ' ',
#  'n_eb1': 24,
#  'n_ordem': '00001',
#  'n_policia': '144',
#  'n_prim': 61,
#  'objectid': 62,
#  'planta': 'PLANTA\\JOSE_GOMES_FERREIRA_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1',
#  'telf': 225097623,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Manoel de Oliveira',
#  'cantina': 0,
#  'carto_1000': 'E4',
#  'cod_freg': '06',
#  'cod_giase': 1312700,
#  'cod_gis': '06170200005',
#  'cod_sgr': '1702',
#  'cod_topo': 'RTANG0',
#  'cp_3': 723,
#  'cp_4': 4150,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Ponte',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvt7b5g8bg30&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23021994&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': 'info@eb1-porto-n36.rcts.pt',
#  'n_eb1': 36,
#  'n_ordem': '00005',
#  'n_policia': '1391',
#  'n_prim': 93,
#  'objectid': 63,
#  'planta': 'PLANTA\\PONTE_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1',
#  'telf': 226102125,
#  'url': 'www.eb23-aldoar.rcts.pt/',
#  'user_reg': 'josepaulo'}
# {'agr': 'Manoel de Oliveira',
#  'cantina': 0,
#  'carto_1000': 'G3',
#  'cod_freg': '01',
#  'cod_giase': 1312839,
#  'cod_gis': '01170200001',
#  'cod_sgr': '1702',
#  'cod_topo': 'RPSOU0',
#  'cp_3': 371,
#  'cp_4': 4100,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'António Aroso',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 226186593,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvv9g2g89trn&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23020032&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 53,
#  'n_ordem': '00001',
#  'n_policia': '36',
#  'n_prim': 137,
#  'objectid': 64,
#  'planta': 'PLANTA\\ANTONIO_AROSO_PLANTA.pdf\r\n',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 226186593,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Manoel de Oliveira',
#  'cantina': 0,
#  'carto_1000': 'F4',
#  'cod_freg': '11',
#  'cod_giase': 1312157,
#  'cod_gis': '11170200008',
#  'cod_sgr': '1702',
#  'cod_topo': 'RDOUR0',
#  'cp_3': 217,
#  'cp_4': 4100,
#  'data_reg': 1245628800000,
#  'descricao': 'Bairro da Vilarinha',
#  'designacao': 'Vilarinha',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 226183835,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvtn44g8bgb2&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23021618&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 39,
#  'n_ordem': '00008',
#  'n_policia': ' ',
#  'n_prim': 99,
#  'objectid': 65,
#  'planta': 'PLANTA\\VILARINHA_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 226183835,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Augusto Gil',
#  'cantina': 0,
#  'carto_1000': 'D10',
#  'cod_freg': '02',
#  'cod_giase': 1312258,
#  'cod_gis': '02170200005',
#  'cod_sgr': '1702',
#  'cod_topo': 'RENOR0',
#  'cp_3': 199,
#  'cp_4': 4000,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Florinhas',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvs8smg8gr3g&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23033776&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': ' ',
#  'n_eb1': 5,
#  'n_ordem': '00005',
#  'n_policia': '28',
#  'n_prim': 12,
#  'objectid': 66,
#  'planta': 'PLANTA\\AINDA_NAO_DISPONIVEL.pdf',
#  'prop': 'Privada (Congregação do Sagrado Coração de Jesus)',
#  't_inst': 'EB1',
#  'telf': 225898492,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Augusto Gil',
#  'cantina': 0,
#  'carto_1000': 'D11',
#  'cod_freg': '02',
#  'cod_giase': 1312293,
#  'cod_gis': '02170200006',
#  'cod_sgr': '1702',
#  'cod_topo': 'RPOVO0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': 'Bairro de Fernão de Magalhães',
#  'designacao': 'Fernão de Magalhães',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvs2d9g8h34s&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23034093&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': ' ',
#  'n_eb1': 4,
#  'n_ordem': '00006',
#  'n_policia': ' ',
#  'n_prim': 9,
#  'objectid': 67,
#  'planta': 'PLANTA\\FERNAO_MAGALHAES_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1',
#  'telf': 225379484,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Augusto Gil',
#  'cantina': 0,
#  'carto_1000': 'C11',
#  'cod_freg': '02',
#  'cod_giase': 1312914,
#  'cod_gis': '02170200007',
#  'cod_sgr': '1702',
#  'cod_topo': 'RDAJS0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Bonfim',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvs04yg8h5gb&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23034144&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 0,
#  'n_ordem': '00007',
#  'n_policia': ' ',
#  'n_prim': 0,
#  'objectid': 68,
#  'planta': 'PLANTA\\AINDA_NAO_DISPONIVEL.pdf',
#  'prop': ' ',
#  't_inst': 'JI',
#  'telf': 225194507,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Augusto Gil',
#  'cantina': 0,
#  'carto_1000': 'D9',
#  'cod_freg': '12',
#  'cod_giase': 1312464,
#  'cod_gis': '12170200002',
#  'cod_sgr': '1702',
#  'cod_topo': 'RJREG0',
#  'cp_3': 293,
#  'cp_4': 4000,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Sto Ildefonso',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvs76wg8g438&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23033696&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 0,
#  'n_ordem': '00002',
#  'n_policia': '305',
#  'n_prim': 0,
#  'objectid': 69,
#  'planta': 'PLANTA\\AINDA_NAO_DISPONIVEL.pdf',
#  'prop': ' ',
#  't_inst': 'JI',
#  'telf': 222084282,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Augusto Gil',
#  'cantina': 0,
#  'carto_1000': 'D10',
#  'cod_freg': '12',
#  'cod_giase': 1312722,
#  'cod_gis': '12170200003',
#  'cod_sgr': '1702',
#  'cod_topo': 'RRDOR0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Fontinha',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvs8n8g8gh1w&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23033776&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 23,
#  'n_ordem': '00003',
#  'n_policia': ' ',
#  'n_prim': 53,
#  'objectid': 70,
#  'planta': 'PLANTA\\FONTINHA_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 222037696,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Rodrigues de Freitas',
#  'cantina': 0,
#  'carto_1000': 'C9',
#  'cod_freg': '04',
#  'cod_giase': 1312205,
#  'cod_gis': '04170200003',
#  'cod_sgr': '1702',
#  'cod_topo': 'RPINH0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': ' ',
#  'designacao': 'Pinheiro',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvrmgrg8g180&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23033862&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'N',
#  'mail': ' ',
#  'n_eb1': 55,
#  'n_ordem': '00003',
#  'n_policia': ' ',
#  'n_prim': 149,
#  'objectid': 71,
#  'planta': 'PLANTA\\AINDA_NAO_DISPONIVEL.pdf',
#  'prop': 'Privada (Montepio Geral)',
#  't_inst': 'EB1',
#  'telf': 222055294,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Cerco',
#  'cantina': 0,
#  'carto_1000': 'E14',
#  'cod_freg': '03',
#  'cod_giase': 1312135,
#  'cod_gis': '03170200011',
#  'cod_sgr': '1702',
#  'cod_topo': 'RCPOR0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': 'Bairro do Cerco do Porto',
#  'designacao': 'Cerco do Porto',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvt54dg8kf6c&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23034327&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 9,
#  'n_ordem': '00011',
#  'n_policia': '590',
#  'n_prim': 23,
#  'objectid': 72,
#  'planta': 'PLANTA\\CERCO_DO_PORTO_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 225101958,
#  'url': ' ',
#  'user_reg': 'josepaulo'}
# {'agr': 'Cerco',
#  'cantina': 0,
#  'carto_1000': 'F13',
#  'cod_freg': '03',
#  'cod_giase': 1312060,
#  'cod_gis': '03170200012',
#  'cod_sgr': '1702',
#  'cod_topo': 'ROURI0',
#  'cp_3': 0,
#  'cp_4': 0,
#  'data_reg': 1245628800000,
#  'descricao': 'Bairro de S. Roque da Lameira',
#  'designacao': 'S. Roque da Lameira',
#  'est': 'Activo',
#  'estat': 'Público',
#  'fax': 0,
#  'foto': 'maps.live.com/default.aspx?v=2&FORM=LMLTCP&cp=qvtz5mg8k0w6&style=o&lvl=2&tilt=-90&dir=0&alt=-1000&scene=23033097&phx=0&phy=0&phscl=1&encType=1&cid=4D1EC098267D9D7C!103',
#  'fraccao': None,
#  'j_i': 'S',
#  'mail': ' ',
#  'n_eb1': 12,
#  'n_ordem': '00012',
#  'n_policia': ' ',
#  'n_prim': 30,
#  'objectid': 73,
#  'planta': 'PLANTA\\S_ROQUE_DA_LAMEIRA_PLANTA.pdf',
#  'prop': 'Municipal',
#  't_inst': 'EB1/JI',
#  'telf': 225107644,
#  'url': ' ',
#  'user_reg': 'josepaulo'}

# %%
for point in data["features"]:
    print(point["geometry"])
# Out:
# {'x': -8.654517789826967, 'y': 41.15109105071595}
# {'x': -8.660382371998741, 'y': 41.15479872870223}
# {'x': -8.647084860003782, 'y': 41.15113765334961}
# {'x': -8.654080762597477, 'y': 41.15151490467868}
# {'x': -8.584446400522738, 'y': 41.17122449990662}
# {'x': -8.66132008163784, 'y': 41.170525595541974}
# {'x': -8.66205092893528, 'y': 41.1704729165955}
# {'x': -8.671509963133849, 'y': 41.17133633540339}
# {'x': -8.616215059442771, 'y': 41.14323419686356}
# {'x': -8.62078339047139, 'y': 41.17638909841599}
# {'x': -8.611529377415076, 'y': 41.179866152647335}
# {'x': -8.611563519482448, 'y': 41.17771633605708}
# {'x': -8.61005620562864, 'y': 41.17632595088096}
# {'x': -8.634232322248335, 'y': 41.14855421867669}
# {'x': -8.621407409178701, 'y': 41.144988891778084}
# {'x': -8.629773793876529, 'y': 41.15438159531659}
# {'x': -8.630081189594074, 'y': 41.15390918888361}
# {'x': -8.616072742202787, 'y': 41.14903137569128}
# {'x': -8.653207730265107, 'y': 41.1707731359961}
# {'x': -8.59843674355199, 'y': 41.148056048733}
# {'x': -8.604445633075336, 'y': 41.14306100847541}
# {'x': -8.616035256445743, 'y': 41.14913863774197}
# {'x': -8.623831626076575, 'y': 41.154033857262654}
# {'x': -8.621407409178701, 'y': 41.144988891778084}
# {'x': -8.617589734810437, 'y': 41.141335888218904}
# {'x': -8.648213992354577, 'y': 41.15373136044149}
# {'x': -8.586682422064298, 'y': 41.16202307208651}
# {'x': -8.599164768608777, 'y': 41.16087730074464}
# {'x': -8.600066014156914, 'y': 41.1439675179957}
# {'x': -8.581035792372912, 'y': 41.17336782456017}
# {'x': -8.57174025071977, 'y': 41.177579205303225}
# {'x': -8.574776643861156, 'y': 41.15908387995104}
# {'x': -8.574992094047646, 'y': 41.159480626650556}
# {'x': -8.579518128661235, 'y': 41.15604998627349}
# {'x': -8.589724323660711, 'y': 41.148208951361816}
# {'x': -8.589580602378037, 'y': 41.15584677141699}
# {'x': -8.582832059644792, 'y': 41.145706869852766}
# {'x': -8.568502834558803, 'y': 41.153136965365405}
# {'x': -8.638366106938092, 'y': 41.161880241531925}
# {'x': -8.639661298118648, 'y': 41.16660769905921}
# {'x': -8.679913095078533, 'y': 41.159600099162674}
# {'x': -8.670342962864844, 'y': 41.15184433709243}
# {'x': -8.661132574613326, 'y': 41.14996541280469}
# {'x': -8.604445633075336, 'y': 41.14306100847541}
# {'x': -8.64570627644131, 'y': 41.17827650115463}
# {'x': -8.641079858675191, 'y': 41.17393685111625}
# {'x': -8.654691126057205, 'y': 41.16958481255368}
# {'x': -8.574255345858973, 'y': 41.16559190046392}
# {'x': -8.616398700427386, 'y': 41.15660068909438}
# {'x': -8.679541241870911, 'y': 41.15926930717176}
# {'x': -8.670359645986371, 'y': 41.15234436158225}
# {'x': -8.64414713229106, 'y': 41.17639661389532}
# {'x': -8.599986741573378, 'y': 41.17021616023818}
# {'x': -8.615093821096922, 'y': 41.1685197940122}
# {'x': -8.614033946120484, 'y': 41.165806980933496}
# {'x': -8.616669360006084, 'y': 41.16359701794343}
# {'x': -8.609310576402773, 'y': 41.16552408922824}
# {'x': -8.599759397389438, 'y': 41.16641741280756}
# {'x': -8.622844915155465, 'y': 41.16859774973018}
# {'x': -8.629194062264938, 'y': 41.169532283280645}
# {'x': -8.658530349174555, 'y': 41.1730964031668}
# {'x': -8.606827361648346, 'y': 41.15958890877244}
# {'x': -8.660191319266133, 'y': 41.161746356443025}
# {'x': -8.669055842812947, 'y': 41.168724978135295}
# {'x': -8.66020745786323, 'y': 41.16425978664963}
# {'x': -8.603410448650768, 'y': 41.15490763092633}
# {'x': -8.59855201758957, 'y': 41.15403603901588}
# {'x': -8.597605738365635, 'y': 41.15327313132537}
# {'x': -8.611377939946365, 'y': 41.15498985566711}
# {'x': -8.60669925588551, 'y': 41.155011153762935}
# {'x': -8.612736216247077, 'y': 41.150950915599196}
# {'x': -8.567443655300542, 'y': 41.16137917416425}
# {'x': -8.573004763125958, 'y': 41.166172512951654}

# %%
attributes = list(data["features"][0]["attributes"].keys())
geometry = list(data["features"][0]["geometry"].keys())
attributes_geometry = attributes + geometry
print(attributes_geometry)
# Out:
# ['objectid', 'cod_topo', 'n_policia', 'cp_4', 'cp_3', 'telf', 'url', 'mail', 'j_i', 't_inst', 'agr', 'est', 'estat', 'carto_1000', 'cod_freg', 'planta', 'n_ordem', 'cod_sgr', 'cod_gis', 'foto', 'fax', 'data_reg', 'user_reg', 'n_eb1', 'n_prim', 'prop', 'cantina', 'descricao', 'fraccao', 'designacao', 'cod_giase', 'x', 'y']

# %%
import folium


m = folium.Map(location=[ 41.14961,  -8.61099], zoom_start=14,tiles="Stamen Terrain",)
#lat = 41.14961, lng =  -8.61099, zoom = 14

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/43/77/0287320dc4fd86ae8847bab6c34b5ec370e836a79c7b0c16680a3d9fd770/folium-0.8.3-py2.py3-none-any.whl (87kB)
#     100% |████████████████████████████████| 92kB 753kB/s ta 0:00:01
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.6/site-packages (from folium)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from folium)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.6/site-packages (from folium)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# Requirement already satisfied: requests in /opt/conda/lib/python3.6/site-packages (from folium)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.6/site-packages (from jinja2->folium)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests->folium)
# Requirement already satisfied: idna<2.8,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests->folium)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests->folium)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests->folium)
# Installing collected packages: branca, folium
# Successfully installed branca-0.3.1 folium-0.8.3
# You are using pip version 9.0.3, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
